# %% [markdown]
# # Intro to Python Workshop: first steps and syntax

# %% [markdown]
# This ipython notebook can be found on my github site:
#
# This notebook serves as an overview of the capabilities of Python. These bites of information are selected to help you write your first 3 useful programs with our help.
#
# * Types, variable declaration and printing
# * Functions
# * Global vs. local variables
# * Import statements: modules
# * Arrays and lists
# * I/O: reading and writing to files
# * Loops and conditional statements
# * Simple data analysis
# * Useful modules/libraries
# * Simple debugging
# * Pair programming projects

# %% [markdown]
# ### Types, variable declaration and printing

# %%
type(8)
# Out:
# int

# %%
type(8.0)
# Out:
# float

# %%
type('c')
# Out:
# str

# %%
type(False)
# Out:
# bool

# %%
type{8}
# Out:
#   File "<ipython-input-13-3922fa707d80>", line 1
#     type{8}
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# | Type       | Example          |
# | ------------- |:-------------:|
# | int      | 4 |
# | float      | 8.0   |
# |string |'awesomeness' |
# |bool | True|

# %%
8+8
# Out:
# 16

# %%
8.+8.
# Out:
# 16.0

# %%
8/7 #keep track of types in divisions
# Out:
# 1

# %%
8./7
# Out:
# 1.1428571428571428

# %%
#this is how we define variables
a = 10
b = 10.
c = a + b
print 'The result is %s .' %(a+b)
print 'The result is also %s .' %(c)
# Out:
# The result is 20.0 .
# The result is also 20.0 .

# %% [markdown]
# ### Functions

# %%
def addition(a,b):
    return a+b

# %%
c = addition(10,10.)
print 'The result is %s .' %(c)
# Out:
# The result is 20.0 .

# %%
addition?

# %%
def addition(a,b):
    """ this function adds two numbers and returns their sum"""
    return a+b

# %%
addition?

# %%
addition.__doc__
# Out:
# ' this function adds two numbers and returns their sum'

# %% [markdown]
# ### Global  vs. local variables

# %%
my_name = "Alex"
def registry_office(old_name):
    to_change = old_name
    new_name = "Joanna"
    return new_name

# %%
print my_name
new_name = registry_office(my_name)
print "New name, new life."
print new_name
print to_change
# Out:
# Alex
# New name, new life.
# Joanna
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ea46be818038> in <module>()
#       3 print "New name, new life."
#       4 print new_name
# ----> 5 print to_change
#
# NameError: name 'to_change' is not defined

# %% [markdown]
# ### Import statements: modules

# %%
import numpy as np # or import numpy

# %%
np.sqrt(4.0)
# Out:
# 2.0

# %%
print np.pi
# Out:
# 3.14159265359

# %% [markdown]
# ### Arrays, lists and dictionaries

# %%
#How to define LISTS
names = ['John', 'Anika', 'Alan', 'Wolfgang']
sort_names = np.sort(names)
print sort_names
# Out:
# ['Alan' 'Anika' 'John' 'Wolfgang']

# %%
#How to define arrays
import numpy as np
array = np.array([0.0, 60., 1.2, 4.5])
square = array**2
sort_number = np.sort(square)
print sort_number
# Out:
# [  0.00000000e+00   1.44000000e+00   2.02500000e+01   3.60000000e+03]

# %%
#How to define dictionaries
new_dictionary = {'name': 'Alex', 'last_name': 'Sokolowska', 'age': 25, 'kids':None}
print new_dictionary['last_name']
print new_dictionary['kids']

#numbers
new_dictionary = {0: 'Alex', 1: 'Sokolowska', 2: 25, 3:None}
print new_dictionary[1]
print new_dictionary.keys()
# Out:
# Sokolowska
# None
# Sokolowska
# [0, 1, 2, 3]

# %% [markdown]
# ### Loops and conditional statements

# %%
def my_greeting(you_came_here=None):
    if you_came_here:
        print "You are awesome!"
    elif not you_came_here:
        print "Buuuuuu!"

my_greeting(you_came_here=True)
my_greeting(you_came_here=False)
# Out:
# You are awesome!
# Buuuuuu!

# %%
fruits = ['apples', 'pears', 'strawberries', 'mangos']
for i in fruits:
    print i

print "\n Next example. \n"

for i in range(len(fruits)):
    print fruits[i]
# Out:
# apples
# pears
# strawberries
# mangos
#
#  Next example.
#
# apples
# pears
# strawberries
# mangos

# %% [markdown]
# ### I/O: writing data to and from a file

# %% [markdown]
# ``` python
# from sys import argv
#
# script, arg1 = argv
#
# def read():
#     fh = open(raw_input("Filename to read:"), 'r')
#     for line in fh:
#         print line
#     fh.close()
#
# def write():
#     new_name = raw_input("Name of a file to write:")
#     fnew = open(new_name, 'w')
#     fnew.write("Hello world! My code in Python gets more and more advanced!")
#     fnew.close()
#
# if arg1=='read':
#     read()
# elif arg1=='write':
#     write()
# else:
#     print "USAGE: python script.py keyword \n where keyword is read or write."
#
#
# ```

# %% [markdown]
# Now, we are going to write a script (so go to your favorite text editor).
# ```python
# #write_data.py
# #we will save data to a text file and a binary file
# import numpy as np
# from sys import argv
# script, arg1 = argv
# database = np.array((['Greta', 60], ['John', 50])) #Name, Age
#
# def save():
#     np.savetxt('./database.txt', database)
#     print "Saved a file."
#
# def load():
#     data = np.genfromtxt('./database.txt', names=['name', 'age'])
#     print "Loaded a file. \n"
#     print "Names in the file: ", data['name']
#     print "Ages in the file: ", data['age']
#
#
#
# if arg=='save':
#     save()
# elif arg=='load':
#     load()
# else:
#     print "USAGE: python write_data.py keyword \n where keyword is save or load."
#
#
# ```

# %% [markdown]
# ### Simple data analysis

# %%
#plot the data
# %matplotlib inline 
import matplotlib.pyplot as plt, numpy as np
x = np.arange(-100,100,0.1)
y = x**2
plt.plot(x,y, label="$f(x)=x^2$")
plt.xlabel("x")
plt.ylabel("$f(x)$")
plt.legend(loc=9)

# %% [markdown]
# ### Useful modules/libraries

# %%
#built-in functions https://docs.python.org/3/library/functions.html
dataset = np.array([7, 20, 0, 100, 2000, 1e67])
print dataset.min() 
print dataset.max()
# Out:
# 0.0
# 1e+67

# %% [markdown]
# ##### modules you might need to check out for the project work
# matplotlib
#
# time
#
# os
#
# numpy

# %% [markdown]
# ### Simple debugging

# %%
#trigger ValueError, NameError, SyntaxError for display
#example of stack overflow search how to do something
#print as a way to debug a code

# %% [markdown]
# ### Algorithmic thinking

# %% [markdown]
# Decompose your problem into smaller sets of instructions before you code it. For each of the following projects, you will be given a blueprint as an example of how to disect a problem into manageable chunks.

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('algorithm.png') #source: http://1.bp.blogspot.com/_m7F1JX_9Q3Y/TO621vouqSI/AAAAAAAAAAM/e6WJjATuwoU/s320/Graphical%2Breprisentaion%2Bof%2Balgorithm.png
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# ### Projects
# #### 1. CODE FROM SCRATCH.
# Be a scientist studying global warming. Show the temperature changes on planet Earth as a function of time. Label axes, put titles on the plot, read the data from a file. Add a legend.
# #### 2. CODE FROM SCRATCH.
# You are working for an oil company and you are double-checking a 20-page long documentation for investors due in 30 minutes. Someone replaced every string "frack" with an f-word, and that includes even the file name. You know Python is your best shot to fix it. Be quick!
# #### 3. FILL IN THE BLANKS.
# We will write a stopwatch together. It is supposed to start counting when you launch your program, as well as print the total elapsed time to your command line (and all-time measurements) when you stop it. At the end, it will show an image logo.png for 5 seconds before the program exits.

# %% [markdown]
# ##### BLUEPRINT 1
# You are writing a script in your text editor. Call it "global_warming.py".
#
# 1. Go to https://climate.nasa.gov/vital-signs/global-temperature/ and download the data. Save it in the .txt format.
# 2. Import all necessary libraries (numpy, matplotlib.pyplot, etc.).
# 3. Load and name each column of the file in your program. Use np.genfromtxt as in the example above. columns: year, annual mean, five-year mean
# 4. Plot the data (x axis: years, y axis: temperature).
# 5. Label the axes. Add a legend.
# 6. Save your figure (look up online how to use plt.savefig).
# 7. Now, edit the program to use functions. Write a function *plot_data(data)* that will do all instructions from (4):(6) when called on data.
#
# ##### BLUEPRINT 2
# You are writing a script in your text editor. Call it "reverse_prank.py".
# 1. Download a file from LINK and save it as .txt .
# 2. You do not need to load any libraries.
# 3. Open a file for reading -- *your_file = open(filename, 'r')* .
# 4. Prompt a user to write a new name of a file(e.g. correct.txt). Corrected text will be written to it. Use function *raw_input('your prompt goes here')* .
# 5. Write a loop over the lines of code *for line in your_file:* that will check in each line if there's an f-word string. How? What about *if "your_string" in line:* ?
# 5. Replace each of them with "frack". See docs how to use *line.replace()* .
# 6. Write *line.replace(necessary arguments)* to yout correct.txt file.
# 7. Don't forget to close both files!
# 8. Write a test function that will go over the file again and print out a statement "Oh no, you missed an f-word!", if it finds an f-word string in this file. Tip: you can set a counter *count=0* before the loop and add 1 to it *count=count+1* *if "your_string" in line* . Then just check the value of *count* at the very end after the loop to print either "Oh no, you missed an f-word!", or "\n\n Good job!!!"
#
# __P.S. Make your code print lines before the change and after. It will help you DEBUG your code!__
#
# ##### BLUEPRINT 3
# You are writing a script in your text editor. Call it "stopwatch.py".
# 1. Download logo.png from HERE.
# 2. Fill in the missing pieces of this code.
#
# ``` python
#
# import os
# import time
#
# def save_your_score(score):
#     #YOU:check if a file "score.txt" is present, see os.path.isfile()
#     #YOU:if it is present, open it with an append flag, if absent, create it (write flag)
#     #YOU:write a score to it (you need to convert it to string) and add to it a newline, e.g. 'Alex' + ' ' + 'Sokolowska' would be an equivalent of 'Alex Sokolowska'
#     #YOU:close the file
#
# def print_all():
#     #YOU:open score.txt for reading
#     #YOU:read the data line by line or as all and print it
#     #YOU:close the file
#
#
# raw_input("Hit enter to start. \n\n")
# print "Here we go!\n"
#
# start = time.time() #time right in this second this gets executed since the beginning of everything - google the "epoch time" ;)
#
# raw_input("Press enter to stop. ")
#
# #YOU:what would be end = ??
# #YOU:Inform user that the program was running X seconds.
# save_your_score(end)
# print_all()
#
# #this set of code plots a goodbye image for 5 seconds.
# import matplotlib.image as mpimg
# import matplotlib.pyplot as plt
# logo = 'logo.png'
# img = mpimg.imread(logo) #gets the array of the image
# plt.imshow(img) #shows the image
# plt.show(block=False) #makes sure you can see it when you type python your_code.py
# plt.pause(5) #waits 5 secs before a shutdown
#
# ```

# %% [markdown]
# ### Now it's time for the last presentation.

# %% [markdown]
# #### Example of startups with Python at its foundations
#
# 1. Adaptive Lab’s Social Media Analytics (SoMA) adaptivelab.com
# 2. Making Deep Learning Fly with RadimRehurek.com
# 3. Large-Scale Productionized Machine Learning at lyst.com
# 4. Large-Scale Social Media Analysis at sme.sh
# 5. Task Queues at lynard.com

# %%
# %matplotlib inline
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('test.001.png')
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
img = mpimg.imread('test.002.png')
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
img = mpimg.imread('test.003.png')
plt.imshow(img)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# # That's all!
